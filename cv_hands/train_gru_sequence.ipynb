# %%
import csv
import os
import glob
import sys
from pathlib import Path

import numpy as np
from sklearn.model_selection import train_test_split

CUDA_BIN = Path(r"C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.5/bin")
CUDNN_BIN_CANDIDATES = [
    Path.cwd() / "third_party" / "cudnn-8.9.7-cuda11" / "bin",
    Path.cwd() / "cv_hands" / "third_party" / "cudnn-8.9.7-cuda11" / "bin",
]

dll_paths = []
if CUDA_BIN.exists():
    dll_paths.append(str(CUDA_BIN))

for candidate in CUDNN_BIN_CANDIDATES:
    if candidate.exists():
        dll_paths.append(str(candidate))
        break

if dll_paths:
    os.environ["PATH"] = ";".join(dll_paths + [os.environ.get("PATH", "")])

print("Python:", sys.executable)
print("CWD:", Path.cwd())
print("DLL search paths:", dll_paths)

import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")
print("Detected GPUs:", gpus)
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

RANDOM_SEED = 42
# Out:
# Python: c:\Users\240358077\Downloads\doneee-main\.venv-train310\Scripts\python.exe
# CWD: c:\Users\240358077\Downloads\doneee-main
# DLL search paths: ['C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.5\\bin', 'c:\\Users\\240358077\\Downloads\\doneee-main\\third_party\\cudnn-8.9.7-cuda11\\bin']
# Detected GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Dataset Path

# %%
model_save_path = 'model/keypoint_classifier/keypoint_sequence_classifier.keras'
tflite_save_path = 'model/keypoint_classifier/keypoint_sequence_classifier.tflite'

# %% [markdown]
# # Parameters

# %%
SEQUENCE_LENGTH = 25
FEATURES_PER_FRAME = 80  # 42 hand + 10 face + 8 pose + 20 relative

# %% [markdown]
# # Load Dataset

# %%
# Load Dataset
csv_files = sorted(glob.glob('Words-Dataset/*_sequence.csv'))
X_sequences = []
y_sequences = []
for csv_file in csv_files:
    data = np.loadtxt(csv_file, delimiter=',', dtype='float32')
    X_sequences.append(data[:, 1:].reshape(-1, SEQUENCE_LENGTH, FEATURES_PER_FRAME))
    y_sequences.extend(data[:, 0])

X_dataset = np.concatenate(X_sequences, axis=0).astype('float32')
y_dataset = np.array(y_sequences, dtype='int32')

# Remove rows with NaN/Inf to prevent val_loss becoming NaN
finite_mask = np.isfinite(X_dataset).all(axis=(1, 2))
removed_non_finite = int((~finite_mask).sum())
if removed_non_finite > 0:
    print(f"Removed non-finite samples: {removed_non_finite}")
    X_dataset = X_dataset[finite_mask]
    y_dataset = y_dataset[finite_mask]

# Extra safety: replace any residual invalid values
X_dataset = np.nan_to_num(X_dataset, nan=0.0, posinf=1e3, neginf=-1e3).astype('float32')

# Convert from 1-based to 0-based indexing for TensorFlow
y_dataset -= 1

# Load labels to determine number of classes
with open('Word-Label/keypoint_sequence_classifier_label.csv', encoding='utf-8-sig') as f:
    keypoint_sequence_classifier_labels = csv.reader(f)
    keypoint_sequence_classifier_labels = [row[0] for row in keypoint_sequence_classifier_labels]
NUM_CLASSES = len(keypoint_sequence_classifier_labels)

# Remove invalid labels outside [0, NUM_CLASSES-1]
valid_label_mask = (y_dataset >= 0) & (y_dataset < NUM_CLASSES)
removed_invalid_labels = int((~valid_label_mask).sum())
if removed_invalid_labels > 0:
    print(f"Removed invalid-label samples: {removed_invalid_labels}")
    X_dataset = X_dataset[valid_label_mask]
    y_dataset = y_dataset[valid_label_mask]

X_train, X_test, y_train, y_test = train_test_split(
    X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED
 )

print(f"Number of classes: {NUM_CLASSES}")
print(f"Labels: {keypoint_sequence_classifier_labels}")
print(f"Dataset shape: {X_dataset.shape}")
print(f"Train/Test: {X_train.shape} / {X_test.shape}")
print(f"Finite check train/test: {np.isfinite(X_train).all()} / {np.isfinite(X_test).all()}")
# Out:
# Removed invalid-label samples: 1
# Number of classes: 155
# Labels: ['你好', '學校', '同學', '屋企人', '鐘意', '唔鐘意', '點解', '彩虹', '謝謝', '等等', '對不起', '聾人', '我', '健聽', '\u2060手語', '現在', '高級', '認識/見面', '開心', '再見', '香港', '早餐', '星期一', '護士', 'ok', '什麼', '麵', '紙巾', '有', '類別', '願望', '星期五', '好', '懲罰', '上個星期', '人', '是', '不是', '需要', '不需要', '幫忙', '醫生', '咖啡', '想', '不想', '爸爸', '媽媽', '父母', '哥哥', '弟弟', '姐姐', '妹妹', '星期日', '爺爺', '星期二', '最後', '分鐘', '兒子', '女兒', '老公', '老婆', '頭痛', '頭盔', '我們', '鋼琴', '你', '喝', '句子', '哪裡', '溫暖', '詞語', '工作', '標籤', '摩托車', '出糧', '不開心', '厲害', '劍擊', '同事', '文職', '網絡', '運動', '學習', '緊張', '茶', '腹瀉', '義工', '功課', '零', '一', '二', '三', '四', '睡覺', '六', '七', '牛奶', '九', '助聽器', '盲', '水', '肚餓', '渴', '飽', '美味', '朋友', '愛', '介紹', '傷心', '生氣', '害怕', '累', '病', '痛', '舒服', '冷', '熱', '大', '小', '遠', '近', '快', '慢', '新', '舊', '平', '貴', '美麗', '聰明', '強壯', '弱', '左', '右', '上面', '下', '前', '後', '最鍾意', '嘗試', '買', '教', '睇', '電話', '電影', '吃', '老師', '會去', '醫院', '假期', '責任', '一齊', '感覺', '帶', '失敗', '成功']
# Dataset shape: (229335, 25, 80)
# Train/Test: (172001, 25, 80) / (57334, 25, 80)
# Finite check train/test: True / True

# %% [markdown]
# # Build LSTM Model

# %%
if 'NUM_CLASSES' not in locals() or NUM_CLASSES == 0:
    print("No classes found. Please collect data first.")
else:
    from tensorflow.keras import layers
    model = tf.keras.models.Sequential([
        layers.Bidirectional(layers.GRU(128, return_sequences=True), input_shape=(SEQUENCE_LENGTH, FEATURES_PER_FRAME)),
        layers.Dropout(0.3),
        
        layers.Bidirectional(layers.GRU(64)),
        layers.Dropout(0.3),
        
        layers.Dense(64, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(NUM_CLASSES, activation='softmax')
    ])

    model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (None, 25, 256)          161280
#  nal)
#
#  dropout_3 (Dropout)         (None, 25, 256)           0
#
#  bidirectional_3 (Bidirectio  (None, 128)              123648
#  nal)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 155)               10075
#
# =================================================================
# Total params: 303,515
# Trainable params: 303,387
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# # Compile and Train Model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

physical_gpus = tf.config.list_physical_devices('GPU')
logical_gpus = tf.config.list_logical_devices('GPU')
print('Physical GPUs:', physical_gpus)
print('Logical GPUs:', logical_gpus)
if logical_gpus:
    print('Training device target: GPU')
else:
    print('Training device target: CPU (GPU not detected)')

print('Validation finite check:', np.isfinite(X_test).all(), np.isfinite(y_test).all())

# Keep only ONE checkpoint file (best model)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path,
    monitor='val_accuracy',
    mode='max',
    verbose=1,
    save_weights_only=False,
    save_best_only=True
)

es_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=20,  # change early stop here
    restore_best_weights=True,
    verbose=1
)
nan_callback = tf.keras.callbacks.TerminateOnNaN()

history = model.fit(
    X_train, y_train,
    epochs=2000,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback, nan_callback]
 )
# Out:
# Physical GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Logical GPUs: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# Training device target: GPU
# Validation finite check: True True
# Epoch 1/2000
# 5373/5376 [============================>.] - ETA: 0s - loss: 0.5681 - accuracy: 0.8765
# Epoch 1: val_accuracy improved from -inf to 0.99402, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 47s 8ms/step - loss: 0.5680 - accuracy: 0.8766 - val_loss: 0.0215 - val_accuracy: 0.9940
# Epoch 2/2000
# 5374/5376 [============================>.] - ETA: 0s - loss: 0.0508 - accuracy: 0.9857
# Epoch 2: val_accuracy improved from 0.99402 to 0.99651, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0508 - accuracy: 0.9857 - val_loss: 0.0089 - val_accuracy: 0.9965
# Epoch 3/2000
# 5376/5376 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9900
# Epoch 3: val_accuracy improved from 0.99651 to 0.99670, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 46s 9ms/step - loss: 0.0348 - accuracy: 0.9900 - val_loss: 0.0094 - val_accuracy: 0.9967
# Epoch 4/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0256 - accuracy: 0.9926
# Epoch 4: val_accuracy improved from 0.99670 to 0.99853, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0257 - accuracy: 0.9926 - val_loss: 0.0042 - val_accuracy: 0.9985
# Epoch 5/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9933
# Epoch 5: val_accuracy did not improve from 0.99853
# 5376/5376 [==============================] - 45s 8ms/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 0.0338 - val_accuracy: 0.9920
# Epoch 6/2000
# 5370/5376 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9942
# Epoch 6: val_accuracy did not improve from 0.99853
# 5376/5376 [==============================] - 46s 9ms/step - loss: 0.0205 - accuracy: 0.9942 - val_loss: 0.0091 - val_accuracy: 0.9970
# Epoch 7/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9948
# Epoch 7: val_accuracy did not improve from 0.99853
# 5376/5376 [==============================] - 45s 8ms/step - loss: 0.0190 - accuracy: 0.9948 - val_loss: 0.0042 - val_accuracy: 0.9985
# Epoch 8/2000
# 5373/5376 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 0.9955
# Epoch 8: val_accuracy improved from 0.99853 to 0.99976, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 46s 9ms/step - loss: 0.0171 - accuracy: 0.9955 - val_loss: 8.0844e-04 - val_accuracy: 0.9998
# Epoch 9/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0143 - accuracy: 0.9962
# Epoch 9: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 46s 8ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.0020 - val_accuracy: 0.9993
# Epoch 10/2000
# 5374/5376 [============================>.] - ETA: 0s - loss: 0.0140 - accuracy: 0.9962
# Epoch 10: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0140 - accuracy: 0.9962 - val_loss: 0.0070 - val_accuracy: 0.9975
# Epoch 11/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9963
# Epoch 11: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0126 - accuracy: 0.9963 - val_loss: 0.0010 - val_accuracy: 0.9997
# Epoch 12/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9966
# Epoch 12: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 0.0030 - val_accuracy: 0.9991
# Epoch 13/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9967
# Epoch 13: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0053 - val_accuracy: 0.9981
# Epoch 14/2000
# 5373/5376 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9971
# Epoch 14: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.0013 - val_accuracy: 0.9998
# Epoch 15/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9967
# Epoch 15: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.0036 - val_accuracy: 0.9990
# Epoch 16/2000
# 5371/5376 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9969
# Epoch 16: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0117 - accuracy: 0.9968 - val_loss: 0.0113 - val_accuracy: 0.9975
# Epoch 17/2000
# 5374/5376 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9966
# Epoch 17: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.0013 - val_accuracy: 0.9997
# Epoch 18/2000
# 5376/5376 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9978
# Epoch 18: val_accuracy did not improve from 0.99976
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0064 - val_accuracy: 0.9983
# Epoch 19/2000
# 5369/5376 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9970
# Epoch 19: val_accuracy improved from 0.99976 to 0.99983, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0107 - accuracy: 0.9970 - val_loss: 6.4580e-04 - val_accuracy: 0.9998
# Epoch 20/2000
# 5373/5376 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9973
# Epoch 20: val_accuracy did not improve from 0.99983
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.0028 - val_accuracy: 0.9991
# Epoch 21/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9973
# Epoch 21: val_accuracy improved from 0.99983 to 0.99984, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0106 - accuracy: 0.9973 - val_loss: 9.2320e-04 - val_accuracy: 0.9998
# Epoch 22/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0093 - accuracy: 0.9973
# Epoch 22: val_accuracy did not improve from 0.99984
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0015 - val_accuracy: 0.9995
# Epoch 23/2000
# 5371/5376 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9974
# Epoch 23: val_accuracy did not improve from 0.99984
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.0019 - val_accuracy: 0.9994
# Epoch 24/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9970
# Epoch 24: val_accuracy improved from 0.99984 to 0.99986, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 3.5715e-04 - val_accuracy: 0.9999
# Epoch 25/2000
# 5370/5376 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9974
# Epoch 25: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.0274 - val_accuracy: 0.9945
# Epoch 26/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9973
# Epoch 26: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 27/2000
# 5369/5376 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9974
# Epoch 27: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 7.8062e-04 - val_accuracy: 0.9998
# Epoch 28/2000
# 5376/5376 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9973
# Epoch 28: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0029 - val_accuracy: 0.9993
# Epoch 29/2000
# 5374/5376 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9970
# Epoch 29: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 42s 8ms/step - loss: 0.0105 - accuracy: 0.9970 - val_loss: 8.3523e-04 - val_accuracy: 0.9997
# Epoch 30/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9976
# Epoch 30: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0089 - accuracy: 0.9976 - val_loss: 6.0287e-04 - val_accuracy: 0.9998
# Epoch 31/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9970
# Epoch 31: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0105 - accuracy: 0.9970 - val_loss: 0.0010 - val_accuracy: 0.9998
# Epoch 32/2000
# 5369/5376 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9975
# Epoch 32: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0088 - accuracy: 0.9975 - val_loss: 6.9622e-04 - val_accuracy: 0.9997
# Epoch 33/2000
# 5371/5376 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9973
# Epoch 33: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0017 - val_accuracy: 0.9995
# Epoch 34/2000
# 5374/5376 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9967
# Epoch 34: val_accuracy did not improve from 0.99986
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0126 - accuracy: 0.9967 - val_loss: 0.0018 - val_accuracy: 0.9994
# Epoch 35/2000
# 5373/5376 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9971
# Epoch 35: val_accuracy improved from 0.99986 to 0.99995, saving model to model/keypoint_classifier\keypoint_sequence_classifier.keras
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 3.0829e-04 - val_accuracy: 0.9999
# Epoch 36/2000
# 5376/5376 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9966
# Epoch 36: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 45s 8ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 5.6851e-04 - val_accuracy: 0.9998
# Epoch 37/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9968
# Epoch 37: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 46s 9ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 38/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9968
# Epoch 38: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0014 - val_accuracy: 0.9997
# Epoch 39/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9971
# Epoch 39: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 9.7545e-04 - val_accuracy: 0.9997
# Epoch 40/2000
# 5374/5376 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9970
# Epoch 40: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.0028 - val_accuracy: 0.9993
# Epoch 41/2000
# 5370/5376 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9965
# Epoch 41: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.0026 - val_accuracy: 0.9993
# Epoch 42/2000
# 5376/5376 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9966
# Epoch 42: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 9.0621e-04 - val_accuracy: 0.9996
# Epoch 43/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9967
# Epoch 43: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.0042 - val_accuracy: 0.9990
# Epoch 44/2000
# 5373/5376 [============================>.] - ETA: 0s - loss: 0.0138 - accuracy: 0.9961
# Epoch 44: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 44s 8ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.0011 - val_accuracy: 0.9998
# Epoch 45/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9963
# Epoch 45: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0126 - accuracy: 0.9963 - val_loss: 9.2919e-04 - val_accuracy: 0.9997
# Epoch 46/2000
# 5373/5376 [============================>.] - ETA: 0s - loss: 0.0137 - accuracy: 0.9959
# Epoch 46: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0137 - accuracy: 0.9959 - val_loss: 6.5167e-04 - val_accuracy: 0.9998
# Epoch 47/2000
# 5374/5376 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9963
# Epoch 47: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 7.3608e-04 - val_accuracy: 0.9998
# Epoch 48/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9964
# Epoch 48: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 52s 10ms/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 7.4575e-04 - val_accuracy: 0.9998
# Epoch 49/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9968
# Epoch 49: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 77s 14ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 9.4809e-04 - val_accuracy: 0.9997
# Epoch 50/2000
# 5374/5376 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 0.9955
# Epoch 50: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 51/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9962
# Epoch 51: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0132 - accuracy: 0.9962 - val_loss: 0.0016 - val_accuracy: 0.9997
# Epoch 52/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9957
# Epoch 52: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 6.2440e-04 - val_accuracy: 0.9999
# Epoch 53/2000
# 5372/5376 [============================>.] - ETA: 0s - loss: 0.0152 - accuracy: 0.9955
# Epoch 53: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0152 - accuracy: 0.9955 - val_loss: 0.0023 - val_accuracy: 0.9995
# Epoch 54/2000
# 5373/5376 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9947
# Epoch 54: val_accuracy did not improve from 0.99995
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 0.0015 - val_accuracy: 0.9996
# Epoch 55/2000
# 5375/5376 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 0.9935
# Epoch 55: val_accuracy did not improve from 0.99995
# Restoring model weights from the end of the best epoch: 35.
# 5376/5376 [==============================] - 43s 8ms/step - loss: 0.0221 - accuracy: 0.9935 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 55: early stopping

# %% [markdown]
# # Save a full SavedModel for OpenVINO conversion
# Add a SavedModel export to ensure weights and graph are fully serialized.

# %%
saved_model_dir = 'model/keypoint_classifier/keypoint_sequence_classifier_savedmodel'
if 'model' in locals():
    os.makedirs(saved_model_dir, exist_ok=True)
    model.save(saved_model_dir)
    print(f"SavedModel exported to: {saved_model_dir}")
else:
    print("Model not found. Train the model first.")
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_7_layer_call_fn, gru_cell_7_layer_call_and_return_conditional_losses, gru_cell_8_layer_call_fn, gru_cell_8_layer_call_and_return_conditional_losses, gru_cell_10_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model/keypoint_classifier/keypoint_sequence_classifier_savedmodel\assets
# INFO:tensorflow:Assets written to: model/keypoint_classifier/keypoint_sequence_classifier_savedmodel\assets
# SavedModel exported to: model/keypoint_classifier/keypoint_sequence_classifier_savedmodel

# %% [markdown]
# # Evaluate Model

# %%
val_loss, val_acc = model.evaluate(X_test, y_test)
print(f'Validation Loss: {val_loss}, Validation Accuracy: {val_acc}')
# Out:
# 1792/1792 [==============================] - 6s 3ms/step - loss: 3.0829e-04 - accuracy: 0.9999
# Validation Loss: 0.00030829140450805426, Validation Accuracy: 0.9999476671218872

# %% [markdown]
# # Convert to TFLite

# %%
model.save(model_save_path)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
converter._experimental_lower_tensor_list_ops = False
tflite_model = converter.convert()

with open(tflite_save_path, 'wb') as f:
    f.write(tflite_model)

print("TFLite model saved.")
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_7_layer_call_fn, gru_cell_7_layer_call_and_return_conditional_losses, gru_cell_8_layer_call_fn, gru_cell_8_layer_call_and_return_conditional_losses, gru_cell_10_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\240358077\AppData\Local\Temp\tmp66hwxcg6\assets
# INFO:tensorflow:Assets written to: C:\Users\240358077\AppData\Local\Temp\tmp66hwxcg6\assets
# TFLite model saved.

# %% [markdown]
# # Test Inference

# %%
# Test Inference
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)

# Add Flex delegate for TensorFlow ops
from tensorflow.lite.python.interpreter import load_delegate
try:
    delegate = load_delegate('libtensorflowlite_flex.so')
    interpreter = tf.lite.Interpreter(model_path=tflite_save_path, experimental_delegates=[delegate])
except:
    print("Flex delegate not available, using standard interpreter")

interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]], dtype=np.float32))
interpreter.invoke()
result = interpreter.get_tensor(output_details[0]['index'])

print("Predicted:", np.argmax(result))
print("Actual:", y_test[0])
# Out:
# Exception ignored in: <function Delegate.__del__ at 0x000001D24212BB50>
# Traceback (most recent call last):
#   File "c:\Users\240358077\Downloads\doneee-main\.venv-train310\lib\site-packages\tensorflow\lite\python\interpreter.py", line 117, in __del__
#     if self._library is not None:
# AttributeError: 'Delegate' object has no attribute '_library'
# Flex delegate not available, using standard interpreter
# Predicted: 102
# Actual: 102

# %%
import sys
import subprocess

try:
    import matplotlib.pyplot as plt
except ModuleNotFoundError:
    print('matplotlib not found, installing...')
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'matplotlib'])
    import matplotlib.pyplot as plt

if 'history' not in locals():
    print('No history found. Run training first (Cell 11).')
else:
    hist = history.history
    epochs = range(1, len(hist.get('accuracy', [])) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, hist.get('accuracy', []), label='train_accuracy')
    plt.plot(epochs, hist.get('val_accuracy', []), label='val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.legend()
    plt.grid(alpha=0.3)

    plt.subplot(1, 2, 2)
    plt.plot(epochs, hist.get('loss', []), label='train_loss')
    plt.plot(epochs, hist.get('val_loss', []), label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training vs Validation Loss')
    plt.legend()
    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()
